# %% [markdown]
# ## Handling low frequency catalogues to compare fluxes

# %%
import matplotlib

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from astropy.coordinates import SkyCoord
from astropy import units as u

# %%
basedir = "/home/mkuiack1/ReferenceCatalogues/"

data = pd.read_csv(basedir+"helmboldt_spectra.csv")
data["F74"] = data["F74"].apply(pd.to_numeric, errors="coerce")
data[" Alp"] = data[" Alp"].apply(pd.to_numeric, errors="coerce")
data[" A"] = data[" A"].apply(pd.to_numeric, errors="coerce")
data[" B"] = data[" B"].apply(pd.to_numeric, errors="coerce")
data[" C"] = data[" C"].apply(pd.to_numeric, errors="coerce")
data[" D"] = data[" D"].apply(pd.to_numeric, errors="coerce")


fluxes  = pd.read_csv(basedir+"helmboldt_fluxes.csv")

# %%
v = np.logspace(1,5)
plt.figure(figsize=(10,10))


for i in data.index:

    spectra = get_spectra(v, data.iloc[i]["F74"], data.iloc[i][" Alp"], 
                          data.iloc[i][" A"], data.iloc[i][" B"], 
                          data.iloc[i][" C"], data.iloc[i][" D"] )
    plt.loglog(v,spectra)

plt.ylim([1e-1,1e4])
# Out:
# /home/mkuiack1/lpfenv/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
#
# /home/mkuiack1/lpfenv/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
#
# /home/mkuiack1/lpfenv/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
#
# /home/mkuiack1/lpfenv/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
# (0.1, 10000.0)

# %%
data
# Out:
#      Unnamed: 0  index       Name  Num   F74   Alp   Fext     A     B   C   D  \
# 0             0      0  J0000+554    7  15.9 -0.93   23.2   NaN   NaN NaN NaN
# 1             1      1  J0003-173   17  18.9 -0.79   24.8  1.31 -0.75 NaN NaN
# 2             2      2  J0004+131    5  16.6 -0.88   15.8   NaN   NaN NaN NaN
# 3             3      3  J0006-000   29  27.0 -0.76   36.6  1.43 -0.70 NaN NaN
# 4             4      4  J0017+792   23  23.9 -0.86   36.3  1.57 -0.87 NaN NaN
# ..          ...    ...        ...  ...   ...   ...    ...   ...   ...  ..  ..
# 383         383    383  J2351-246    6  20.7 -1.04   26.6   NaN   NaN NaN NaN
# 384         384    384  J2351+644    8  39.3 -1.18    145  1.91 -0.95 NaN NaN
# 385         385    385  J2354+326    8  17.4 -0.96   18.6  1.33 -0.99 NaN NaN
# 386         386    386  J2357-345    6  47.4 -1.68  148.9   NaN   NaN NaN NaN
# 387         387    387  J2359+440   20  18.4 -0.94   29.2  1.45 -0.97 NaN NaN
#
#          rms       ra   dec
# ...
