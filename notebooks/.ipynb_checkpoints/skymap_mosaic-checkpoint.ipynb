# %%
import numpy as np
import pandas as pd
import healpy as hp
import h5py
import glob
import time

import matplotlib.pyplot as plt

from astropy.io import fits
from astropy.wcs import WCS
from astropy import units as u
from astropy.coordinates import SkyCoord

# %matplotlib inline

# %%
# different image location
# images =glob.glob("fits/*.fits")

# Different location 
beam_file = "/home/kuiack/AARTFAAC_beamsim/LBAOUTER_AARTFAAC_beamshape_60MHz.hdf5"
beam_model = np.array(h5py.File(beam_file).get('lmbeamintensity_norm'))

# %%
meshx, meshy = np.meshgrid(np.linspace(0,2100,2100),
                           np.linspace(0,2100,2100))


# meshx, meshy = np.meshgrid(np.linspace(0,1023,1024),np.linspace(0,1023,1024))

# %%
2100./1024.
# Out:
# 2.05078125

# %%
# import scipy.ndimage

beam_model = scipy.ndimage.zoom(beam_model, 2.05078125, order=3)

# %%
NSIDE = 256
print(np.rad2deg(hp.pixelfunc.nside2resol(NSIDE)))
# Out:
# 0.229032427454

# %%
tmp_img = np.array(fits.open(_img)[0].data[0,0,:,:],dtype=np.float)

# %%
np.shape(tmp_img)
# Out:
# (2100, 2100)

# %%
_img = "/data/20190329/2019-03-29T07:48:13-S314-B8.fits"

# %%
image_list = sorted(glob.glob("/home/kuiack/A12_frames/*"))[::60]
image_list = np.append(image_list,sorted(glob.glob("/mnt/ads001/A12_slices/slices/A12_test_cleanborder_DI_SUB_SC2-I-image-pb.fits"))[::6])

for i in image_list:
    print i
# Out:
# /home/kuiack/A12_frames/A12_masked_t0000.fits
# /home/kuiack/A12_frames/A12_masked_t0060.fits
# /home/kuiack/A12_frames/A12_masked_t0120.fits
# /home/kuiack/A12_frames/A12_masked_t0180.fits
# /home/kuiack/A12_frames/A12_masked_t0240.fits
# /home/kuiack/A12_frames/A12_masked_t0302.fits
# /home/kuiack/A12_frames/A12_masked_t0362.fits
# /home/kuiack/A12_frames/A12_masked_t0422.fits
# /home/kuiack/A12_frames/A12_masked_t0482.fits
# /home/kuiack/A12_frames/A12_masked_t0542.fits
# /mnt/ads001/A12_slices/slices/A12_test_cleanborder_DI_SUB_SC2-I-image-pb.fits

# %%
tmp_img[index]
# Out:
# array([ nan,  nan,  nan, ...,  nan,  nan,  nan])

# %%
NSIDE = 256

hp_index = np.arange(hp.nside2npix(NSIDE))

# %%
sky_map = pd.DataFrame({"idotw":np.zeros(len(hp_index)), 
                        "i":np.zeros(len(hp_index)),
                        "w":np.zeros(len(hp_index)), 
                        "n":np.zeros(len(hp_index))}, index = hp_index )



n = 1
for _img in image_list:
    t1 = time.time()
    
    image_wcs = WCS(_img)
    tmp_img = np.array(fits.open(_img)[0].data[0,0,:,:],dtype=np.float)
    ra, dec,notused, nnotused = image_wcs.wcs_pix2world(meshx,meshy,1,1,1)
    
    index = (np.isfinite(tmp_img) & np.isfinite(dec) & np.isfinite(ra) & (beam_model != 0.0))
    
    pix_index = hp.pixelfunc.ang2pix(NSIDE,ra[index],dec[index],lonlat=True)    
    
    
    
    sky_map.at[pix_index, "idotw"] = sky_map.iloc[pix_index]["idotw"] + tmp_img[index]*beam_model[index]
    sky_map.at[pix_index, "i"] = sky_map.iloc[pix_index]["i"] + tmp_img[index]
    sky_map.at[pix_index, "w"] = sky_map.iloc[pix_index]["w"] + beam_model[index]
    sky_map.at[pix_index, "n"] = sky_map.iloc[pix_index]["n"] +  np.ones(len(beam_model[index]))
    print n,"/", len(image_list), time.time() - t1
    n += 1
# Out:
# 1 / 11 3.50461888313
# 2 / 11 3.4117128849
# 3 / 11 3.39974188805
# 4 / 11 3.40943384171
# 5 / 11 3.26957392693
# 6 / 11 3.5642220974
# 7 / 11 3.48187208176
# 8 / 11 3.42572498322
# 9 / 11 3.40338301659
# 10 / 11 3.88389515877
# 11 / 11 3.67464804649

# %%
hp.mollview(sky_map["i"],min=-1000, max=1000,  cmap="YlGnBu_r", title="unweighted mean")

# %%
m = (sky_map["idotw"]/sky_map["w"])
plt.figure(1, figsize=(16,10))
hp.mollview(m, min=-10,max=20, cmap="YlGnBu_r", title="weighted mean", fig=1)

# %%
hp.mollview(sky_map["n"], cmap="YlGnBu_r")

# %%
hp.mollview?

# %%
image_list
# Out:
# ['/data/ASf_20190127-2/2019-01-26T13:59:27-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T00:18:45-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T00:35:32-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T00:52:18-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T01:09:05-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T01:25:52-S316.7-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T01:42:38-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T01:59:25-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T02:16:12-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T02:32:58-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T02:49:45-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T03:06:31-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T03:23:21-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T03:40:09-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T03:57:03-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T04:13:59-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T04:30:52-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T04:47:42-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T05:04:37-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T05:21:30-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T05:38:20-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T05:55:08-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T06:11:57-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T06:28:48-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T06:45:40-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T07:02:31-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T07:19:17-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T07:36:05-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T07:52:54-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T08:09:40-S316.3-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T08:26:31-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T08:43:22-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T09:00:11-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T09:17:01-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T09:33:52-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T09:50:38-S316.7-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T10:07:27-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T10:24:15-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T10:41:03-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T13:10:51-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T13:27:38-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T13:44:24-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T14:01:11-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T14:17:58-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T14:34:44-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T14:51:31-S316.7-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T15:08:18-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T15:25:05-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T15:41:52-S316.5-B8.fits',
#  '/data/ASf_20190127-2/2019-01-27T15:58:38-S316.5-B8.fits']

# %%
hp.write_map("ASf_20190127.fits", m)

# %%
pwd
# Out:
# u'/afhome/kuiack/scratchpad/notebooks'
