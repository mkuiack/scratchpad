# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import astropy.io.fits as fits
import glob

# %matplotlib notebook

# %%
image_list = glob.glob("/data/20200206/*fits")
print len(image_list)
# Out:
# 24375

# %%
image_list[2459]
# Out:
# '/data/20200206/2020-02-06T12:12:28-S314-B8.fits'

# %%
img_obj = fits.open(image_list[2459])[0]

# %%
img_data = img_obj.data[0,0,:,:]

# %%
plt.figure(figsize=(5,5))
plt.imshow(img_data, vmin=-10, vmax=30, origin="lower" )
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
image_list[2459]
# Out:
# '/data/20200206/2020-02-06T12:12:28-S314-B8.fits'
